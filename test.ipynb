# %%
import target
targets = target.targets_from_TNS_csv("tns_search(1-500).csv")
# Out:
# Querying lightcurve for ZTF26aafsxig...
# Querying lightcurve for ZTF26aaffpvx...
# Querying lightcurve for ZTF26aaezpbh...
# Querying lightcurve for ZTF26aaeoptc...
# Querying lightcurve for ZTF26aaervms...
# Querying lightcurve for ZTF26aadpylg...
# Querying lightcurve for ZTF26aabzhrq...
# Querying lightcurve for ZTF26aaclbkw...
# Querying lightcurve for ZTF26aabdrrs...
# Querying lightcurve for ZTF26aaadpeh...
# Querying lightcurve for ZTF26aaaqelu...
# Querying lightcurve for ZTF26aaadqxr...
# Querying lightcurve for ZTF26aaakzsi...
# Querying lightcurve for ZTF25aciuoxf...
# ---------------------------------------------------------------------------
# ObjectNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import target
# ----> 2 targets = target.targets_from_TNS_csv("tns_search(1-500).csv")
#
# File ~/TD_Data_Project/target.py:47, in targets_from_TNS_csv(filename)
#      45 targets = []
# ...

# %%
print(targets)
