# %%
import target
targets = target.targets_from_TNS_csv("tns_search(1-500).csv", stop_early=1)
# Out:
# Querying lightcurve for ZTF26aafsxig...

# %%
for target in targets:
    #finding the observations where we have multiple fids
# Out:
#   Cell In[2], line 2
#     #finding the observations where we have multiple fids
#                                                           ^
# _IncompleteInputError: incomplete input

# %%
targets[0][0].A_SFD
# Out:
# np.float64(0.119)

# %%
# Out:
# 0.02728

# %%
targets[0].extinction
# Out:
# <Table length=25>
# Filter_name  LamEff A_over_E_B_V_SandF A_SandF A_over_E_B_V_SFD  A_SFD
#              micron                      mag                      mag
#     str8    float64      float64       float64     float64      float64
# ----------- ------- ------------------ ------- ---------------- -------
#      CTIO U  0.3734              4.107   0.129            4.968   0.156
#      CTIO B  0.4309              3.641   0.114            4.325   0.136
#      CTIO V  0.5517              2.682   0.084             3.24   0.102
#      CTIO R   0.652              2.119   0.067            2.634   0.083
#      CTIO I  0.8007              1.516   0.048            1.962   0.062
#    DSS-II g  0.4621              3.381   0.106            3.907   0.123
#    DSS-II r  0.6546              2.088   0.066            2.649   0.083
#    DSS-II i  0.8111              1.487   0.047            1.893   0.059
#      SDSS u  0.3587              4.239   0.133            5.155   0.162
# ...
